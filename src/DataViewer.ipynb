# %%
import importer
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = 'Elapsed Time'
y_data = 'Distance'

data_set = importer.Data()
data = data_set.get_data([x_data, y_data, 'Activity Gear'])

data = importer.partition(data, 'Activity Gear')

X_mtb = data['Roscoe 8'][x_data]
Y_mtb = data['Roscoe 8'][y_data]
X_road = data['Carrera Zelos'][x_data]
Y_road = data['Carrera Zelos'][y_data]
fig, ax = plt.subplots()
ax.scatter(X_mtb, Y_mtb, c='blue')
ax.scatter(X_road, Y_road, c='red')
ax.set_xlabel(x_data)
ax.set_ylabel(y_data)
plt.show()
