# %%
import importer
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = 'Wind Gust'
y_data = 'Average Watts'

data_set = importer.Data()
data0 = data_set.get_data([x_data, y_data, 'Activity Gear'])

data0 = importer.partition(data0, 'Activity Gear')

X_mtb = data0['Roscoe 8'][x_data]
Y_mtb = data0['Roscoe 8'][y_data]
X_road = data0['Carrera Zelos'][x_data]
Y_road = data0['Carrera Zelos'][y_data]
fig0, ax = plt.subplots()
ax.scatter(X_mtb, Y_mtb, c='blue', label='MTB')
ax.scatter(X_road, Y_road, c='red', label='Road')
ax.set_xlabel(x_data)
ax.set_ylabel(y_data)
ax.legend()
plt.show()

# %%
x_data = 'Perceived Relative Effort'
y_data = 'Moving Time'

data1 = data_set.get_data([x_data, y_data, 'Activity Gear'])

data1 = importer.partition(data1, 'Activity Gear')

X_mtb = data1['Roscoe 8'][x_data]
Y_mtb = data1['Roscoe 8'][y_data]
X_road = data1['Carrera Zelos'][x_data]
Y_road = data1['Carrera Zelos'][y_data]
fig1, ax = plt.subplots()
ax.scatter(X_mtb, Y_mtb, c='blue', label='MTB')
ax.scatter(X_road, Y_road, c='red', label='Road')
ax.set_xlabel(x_data)
ax.set_ylabel(y_data)
ax.legend()
plt.show()

# %%
x_data = 'Distance'
y_data = 'Moon Phase'

data1 = data_set.get_data([x_data, y_data, 'Activity Gear'])

data1 = importer.partition(data1, 'Activity Gear')

X_mtb = data1['Roscoe 8'][x_data]
Y_mtb = data1['Roscoe 8'][y_data]
X_road = data1['Carrera Zelos'][x_data]
Y_road = data1['Carrera Zelos'][y_data]
fig2, ax = plt.subplots()
ax.scatter(X_mtb, Y_mtb, c='blue', label='MTB')
ax.scatter(X_road, Y_road, c='red', label='Road')
ax.set_xlabel(x_data)
ax.set_ylabel(y_data)
ax.legend()
plt.show()
