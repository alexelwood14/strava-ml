# %%
import importer
import numpy as np
import matplotlib.pyplot as plt

# %%
X = ['W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W']
prob = X.count('W') / (len(X))

# %%
prior = np.linspace(0,1,100)
likelihood = 1
minimiser = 1
posterior = (likelihood * prior) / minimiser

fig, ax = plt.subplots()
plt.plot(prior, posterior, '-r', label='y=2x+1')
plt.show()
